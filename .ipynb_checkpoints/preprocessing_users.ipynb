# %%
import pandas as pd

# Using double backslashes to decode (instead of unicode escape sequence)
movies_names_df = pd.read_csv("C:\\Users\\Jrv12\\Desktop\\Recommendation System\\recommendationSystem\\datasets\\movies.csv")
ratings_df = pd.read_csv("C:\\Users\\Jrv12\\Desktop\\Recommendation System\\recommendationSystem\\datasets\\ratings.csv")
tags_df = pd.read_csv("C:\\Users\\Jrv12\\Desktop\\Recommendation System\\recommendationSystem\\datasets\\tags.csv")

# %%
movies_names_df.head(1)['title']
# Out:
# 0    Toy Story (1995)
# Name: title, dtype: object

# %%
ratings_df.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
# Merge the ratings DataFrame with the movies_names DataFrame
ratings_df = ratings_df.merge(movies_names_df, on='movieId', how='left')

# %%
ratings_df.head(5)
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
#
#                                               title  \
# 0                               Pulp Fiction (1994)
# 1  Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2  Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3                                Underground (1995)
# 4                        Singin' in the Rain (1952)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1                        Drama
# 2                        Drama
# 3             Comedy|Drama|War
# 4       Comedy|Musical|Romance

# %%
# Extract movie date from the title using regular expression
ratings_df['movie_date'] = ratings_df['title'].str.extract(r'\((\d{4})\)')

# Remove the movie date from the title column
ratings_df['title'] = ratings_df['title'].str.replace(r'\s*\(\d{4}\)', '')
# Out:
# C:\Users\Jrv12\AppData\Local\Temp\ipykernel_19856\940642826.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   ratings_df['title'] = ratings_df['title'].str.replace(r'\s*\(\d{4}\)', '')

# %%
ratings_df.head(5)
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
#
#                                        title                       genres  \
# 0                               Pulp Fiction  Comedy|Crime|Drama|Thriller
# 1  Three Colors: Red (Trois couleurs: Rouge)                        Drama
# 2  Three Colors: Blue (Trois couleurs: Bleu)                        Drama
# 3                                Underground             Comedy|Drama|War
# 4                        Singin' in the Rain       Comedy|Musical|Romance
#
#   movie_date
# 0       1994
# 1       1994
# 2       1993
# 3       1995
# 4       1952

# %%
tags_df.head(5)
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
ratings_df
# Out:
#           userId  movieId  rating   timestamp  \
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
#                                               title  \
# 0                                      Pulp Fiction
# 1         Three Colors: Red (Trois couleurs: Rouge)
# 2         Three Colors: Blue (Trois couleurs: Bleu)
# 3                                       Underground
# 4                               Singin' in the Rain
# ...                                             ...
# ...

# %%
tags_df = tags_df.dropna(how='any')
ratings_df = ratings_df.dropna(how='any')

# %%
# Check memory usage after optimization
print(ratings_df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24988355 entries, 0 to 25000094
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   userId      int64
#  1   movieId     int64
#  2   rating      float64
#  3   timestamp   int64
#  4   title       object
#  5   genres      object
#  6   movie_date  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.9 GB
# None

# %%
# Check memory usage after optimization
print(ratings_df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24988355 entries, 0 to 25000094
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   userId      int64
#  1   movieId     int64
#  2   rating      float64
#  3   timestamp   int64
#  4   title       object
#  5   genres      object
#  6   movie_date  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.9 GB
# None

# %%
print(tags_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1093344 entries, 0 to 1093359
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   userId     1093344 non-null  int64
#  1   movieId    1093344 non-null  int64
#  2   tag        1093344 non-null  object
#  3   timestamp  1093344 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 41.7+ MB
# None

# %%
ratings_df.head(5)
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
#
#                                        title                       genres  \
# 0                               Pulp Fiction  Comedy|Crime|Drama|Thriller
# 1  Three Colors: Red (Trois couleurs: Rouge)                        Drama
# 2  Three Colors: Blue (Trois couleurs: Bleu)                        Drama
# 3                                Underground             Comedy|Drama|War
# 4                        Singin' in the Rain       Comedy|Musical|Romance
#
#   movie_date
# 0       1994
# 1       1994
# 2       1993
# 3       1995
# 4       1952

# %%
ratings_df = ratings_df.rename(columns={'timestamp_x': 'timestamp'})

# %%
tags_df.head(5)
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
ratings_df = ratings_df.merge(tags_df, on=['timestamp'], how='inner')

# %%
ratings_df
# Out:
#        userId_x  movieId_x  rating   timestamp  \
# 0             3       7373     4.0  1439473075
# 1             4       8874     4.0  1573938641
# 2             4      49396     3.5  1573941006
# 3             4      87430     1.0  1573937327
# 4            12        926     4.5  1266934991
# ...         ...        ...     ...         ...
# 49940    162534      74275     3.0  1527452901
# 49941    162534      74275     3.0  1527452901
# 49942    162534      74275     3.0  1527452901
# 49943    162534      74275     3.0  1527452901
# 49944    162534      74275     3.0  1527452901
#
#                                     title                           genres  \
# 0                                 Hellboy  Action|Adventure|Fantasy|Horror
# 1                       Shaun of the Dead                    Comedy|Horror
# 2      Tenacious D in The Pick of Destiny         Adventure|Comedy|Musical
# 3                           Green Lantern          Action|Adventure|Sci-Fi
# ...

# %%
ratings_df.head(10)
# Out:
#    userId_x  movieId_x  rating   timestamp  \
# 0         3       7373     4.0  1439473075
# 1         4       8874     4.0  1573938641
# 2         4      49396     3.5  1573941006
# 3         4      87430     1.0  1573937327
# 4        12        926     4.5  1266934991
# 5        44      67197     4.0  1489523370
# 6        44      70336     4.0  1489523409
# 7        44      99112     5.0  1489523376
# 8        57       1721     1.0  1142403389
# 9        71      50872     4.0  1482966673
#
#                                 title                                genres  \
# 0                             Hellboy       Action|Adventure|Fantasy|Horror
# 1                   Shaun of the Dead                         Comedy|Horror
# 2  Tenacious D in The Pick of Destiny              Adventure|Comedy|Musical
# 3                       Green Lantern               Action|Adventure|Sci-Fi
# 4                       All About Eve                                 Drama
# ...

# %%
ratings_df = ratings_df[['userId_x', 'movieId_x', 'rating', 'timestamp', 'title', 'genres', 'movie_date', 'tag']]

# %%
ratings_df
# Out:
#        userId_x  movieId_x  rating   timestamp  \
# 0             3       7373     4.0  1439473075
# 1             4       8874     4.0  1573938641
# 2             4      49396     3.5  1573941006
# 3             4      87430     1.0  1573937327
# 4            12        926     4.5  1266934991
# ...         ...        ...     ...         ...
# 49940    162534      74275     3.0  1527452901
# 49941    162534      74275     3.0  1527452901
# 49942    162534      74275     3.0  1527452901
# 49943    162534      74275     3.0  1527452901
# 49944    162534      74275     3.0  1527452901
#
#                                     title                           genres  \
# 0                                 Hellboy  Action|Adventure|Fantasy|Horror
# 1                       Shaun of the Dead                    Comedy|Horror
# 2      Tenacious D in The Pick of Destiny         Adventure|Comedy|Musical
# 3                           Green Lantern          Action|Adventure|Sci-Fi
# ...

# %%
# Drop duplicate rows
df_without_duplicates = ratings_df.drop_duplicates()

# %%
ratings_df = ratings_df.drop_duplicates(subset=['userId_x', 'movieId_x'])

# %%
ratings_df.head(5)
# Out:
#    userId_x  movieId_x  rating   timestamp  \
# 0         3       7373     4.0  1439473075
# 1         4       8874     4.0  1573938641
# 2         4      49396     3.5  1573941006
# 3         4      87430     1.0  1573937327
# 4        12        926     4.5  1266934991
#
#                                 title                           genres  \
# 0                             Hellboy  Action|Adventure|Fantasy|Horror
# 1                   Shaun of the Dead                    Comedy|Horror
# 2  Tenacious D in The Pick of Destiny         Adventure|Comedy|Musical
# 3                       Green Lantern          Action|Adventure|Sci-Fi
# 4                       All About Eve                            Drama
#
#   movie_date               tag
# 0       2004        psychology
# 1       2004           dungeon
# 2       2006  Alfred Hitchcock
# 3       2011          mindfuck
# 4       1950   talking animals

# %%
ratings_df = ratings_df[['userId_x', 'title', 'rating', 'title']]

# %%
ratings_df
# Out:
#        userId_x                               title  rating  \
# 0             3                             Hellboy     4.0
# 1             4                   Shaun of the Dead     4.0
# 2             4  Tenacious D in The Pick of Destiny     3.5
# 3             4                       Green Lantern     1.0
# 4            12                       All About Eve     4.5
# ...         ...                                 ...     ...
# 49918    162521                          Epic Movie     1.5
# 49919    162526           Shawshank Redemption, The     4.0
# 49920    162526                    Truman Show, The     4.5
# 49921    162534                          Hours, The     3.0
# 49922    162534           I Love You Phillip Morris     3.0
#
#                                     title
# 0                                 Hellboy
# 1                       Shaun of the Dead
# 2      Tenacious D in The Pick of Destiny
# 3                           Green Lantern
# ...

# %%
ratings_df = ratings_df[['userId_x', 'title', 'rating']]

# %%
ratings_df
# Out:
#        userId_x                               title  \
# 0             3                             Hellboy
# 1             4                   Shaun of the Dead
# 2             4  Tenacious D in The Pick of Destiny
# 3             4                       Green Lantern
# 4            12                       All About Eve
# ...         ...                                 ...
# 49918    162521                          Epic Movie
# 49919    162526           Shawshank Redemption, The
# 49920    162526                    Truman Show, The
# 49921    162534                          Hours, The
# 49922    162534           I Love You Phillip Morris
#
#                                     title  rating
# 0                                 Hellboy     4.0
# 1                       Shaun of the Dead     4.0
# 2      Tenacious D in The Pick of Destiny     3.5
# 3                           Green Lantern     1.0
# 4                           All About Eve     4.5
# ...

# %%
ratings_df = ratings_df.drop_duplicates()

# %%
ratings_df.shape
# Out:
# (42100, 4)

# %%
ratings_df
# Out:
#        userId_x                      original_title  \
# 0             3                             Hellboy
# 1             4                   Shaun of the Dead
# 2             4  Tenacious D in The Pick of Destiny
# 3             4                       Green Lantern
# 4            12                       All About Eve
# ...         ...                                 ...
# 49918    162521                          Epic Movie
# 49919    162526           Shawshank Redemption, The
# 49920    162526                    Truman Show, The
# 49921    162534                          Hours, The
# 49922    162534           I Love You Phillip Morris
#
#                                     title  rating
# 0                                 Hellboy     4.0
# 1                       Shaun of the Dead     4.0
# 2      Tenacious D in The Pick of Destiny     3.5
# 3                           Green Lantern     1.0
# 4                           All About Eve     4.5
# ...

# %%
ratings_df.columns.values[2] = 'title'

# %%
ratings_df = ratings_df[['userId_x', 'original_title', 'rating']]

# %%
ratings_df
# Out:
#        userId_x                      original_title  rating
# 0             3                             Hellboy     4.0
# 1             4                   Shaun of the Dead     4.0
# 2             4  Tenacious D in The Pick of Destiny     3.5
# 3             4                       Green Lantern     1.0
# 4            12                       All About Eve     4.5
# ...         ...                                 ...     ...
# 49918    162521                          Epic Movie     1.5
# 49919    162526           Shawshank Redemption, The     4.0
# 49920    162526                    Truman Show, The     4.5
# 49921    162534                          Hours, The     3.0
# 49922    162534           I Love You Phillip Morris     3.0
#
# [42100 rows x 3 columns]

# %%
ratings_df.reset_index(drop=True, inplace=True)

# %%
# %store ratings_df
# Out:
# Stored 'ratings_df' (DataFrame)
